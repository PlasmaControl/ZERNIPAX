# %%
import sys
import os

sys.path.insert(0, os.path.abspath("."))
sys.path.append(os.path.abspath("../"))

# %%
import numpy as np
from zernipax.basis import ZernikePolynomial
from zernipax.plotting import plot_basis, plot_mode, plot_modes
import matplotlib.pyplot as plt

# %%
modes = np.array([[6,2]])
modes = np.array([[6,2], [1,1], [9,3]])
plot_modes(modes, rho=100, theta=100, figsize=(8,8));
# Out:
# WARNING:2026-02-24 14:53:52,427:jax._src.xla_bridge:794: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
plot_mode(mode=[6,2], rho=100, theta=100, figsize=(8,8));

# %%
basis = ZernikePolynomial(L=5, M=5, spectral_indexing="ansi", sym=False)
plot_basis(basis);

# %%
basis = ZernikePolynomial(L=5, M=5, spectral_indexing="ansi", sym="cos")
plot_basis(basis);

# %%
basis = ZernikePolynomial(L=5, M=5, spectral_indexing="ansi", sym="sin")
plot_basis(basis);

# %%
basis = ZernikePolynomial(L=5, M=5, spectral_indexing="fringe", sym=False)
plot_basis(basis);

# %%
basis = ZernikePolynomial(L=5, M=5, spectral_indexing="ansi", sym=False)
plot_basis(basis);
